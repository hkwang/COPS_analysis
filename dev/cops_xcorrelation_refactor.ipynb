# %%
import os
os.chdir('..')

import nmrglue as ng
import numpy as np
from cops_analysis import cops_analyze
from cops_prediction import gaussian
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralBiclustering

# %%
#predict sequential peaks
class int_seq_match():
    def __init__(self, cops_analyzer, cops_mode='HCA', peak_table_dir=None):
        self.cops_mode = cops_mode
        self.cops_analyzer = cops_analyzer
        

        self.load_peak_table(peak_table_dir)
        self.load_1Ds()
        self.list_mode = True

    
        print("done!")
            
        
    def load_peak_table(self, peak_table_dir):
        '''
        DEFINITION
        __________
        Loads a peak table containing labeled peaks. reads chemical shifts and whether or not peak is sequential or internal.

        PARAMETERS
        __________
        peak_table_dir: string
        location of SPARKY peak table

        OUTPUTS
        __________
        None. This fucntion updates the shifts_array instance and the tb_sequential instance with the peaks from the table.
        '''
        if self.cops_mode == 'HCA':
            self.tb = pd.read_fwf(peak_table_dir, infer_nrows=300)
            self.tb = self.tb.rename(columns={'w1':'CA','w2':'HN'})
                
            self.tb['is_sequential']=np.append([False], [len(self.tb['Assignment'][i+1]) > len(self.tb['Assignment'][i]) for i in range(len(self.tb)-1)])
            self.shifts_array = self.tb[['CA', 'HN']].to_numpy(dtype=np.float32)
            
        elif self.cops_mode == 'HNCA':
            self.tb = pd.read_fwf(peak_table_dir, infer_nrows=300)
            self.tb = self.tb.rename(columns={'w1':'CA','w2':'N','w3':'HN'})

            self.tb['is_sequential']=np.append([False], [len(self.tb['Assignment'][i+1]) > len(self.tb['Assignment'][i]) for i in range(len(self.tb)-1)])
            self.shifts_array = self.tb[['CA', 'N', 'HN']].to_numpy(dtype=np.float32)
            self.shifts_array[:,[0,1]]=self.shifts_array[:,[1,0]]
        
        #self.shifts_array = self.shifts_array[self.tb['is_sequential']]
        self.tb_sequential = self.tb[self.tb['is_sequential']]
        self.tb_internal = self.tb[~self.tb['is_sequential']]
    

    def load_1Ds(self, C_center=None):
        '''
        DEFINITION
        __________
        Loads 1D 13C slices of peaks in the peak table, centered at C_center (ppm).  
        '''
        ca = self.cops_analyzer
        #extract 1Ds from absolute center
        temp_shifts = np.copy(self.shifts_array)
        if C_center != None:
            if self.cops_mode == 'HNCA':
                temp_shifts[:,1] = C_center
            elif self.cops_mode == 'HCA':
                temp_shifts[:,0] = C_center

        self.shifts_index = np.array([[[ca.cop_unit_convs[k][j](temp_shifts[i][j], "ppm") for k in range(ca.cop_num)] for j in range(3)] for i in range(len(temp_shifts))])
        self.slices = np.array([np.array([ca.extract1D(temp_shifts[j], ca.cop_dats[i], ca.cop_unit_convs[i],sw=90, normalize=True)[1] for i in range(ca.cop_num)]).reshape(-1) for j in range(len(temp_shifts))])
        
        try:
            #this would be faster with a vectorizable nmrglue unit conversion object
            self.slices = np.array([np.array([ca.extract1D(temp_shifts[j], ca.cop_dats[i], ca.cop_unit_convs[i],sw=90, normalize=True)[1] for i in range(ca.cop_num)]).reshape(-1) for j in range(len(temp_shifts))])
            self.slices_wide = np.array([np.array([ca.extract1D(temp_shifts[j], ca.cop_dats[i], ca.cop_unit_convs[i],sw=150, normalize=True)[1] for i in range(ca.cop_num)]).reshape(-1) for j in range(len(temp_shifts))])
        except:
            raise ValueError("Error with loading 1D slices. Check peak list")

# %%
# %%time
A = a.cops_analyzer.cop_dats
indices=[[1,3,3,50,2,4],[15,17,3,50,19,22]]
def slices(index):
    return [A[i][index[0]:index[1],index[2]:index[3], index[4]:index[5]] for i in range(len(A))]
P = map(slices, indices)
print(np.fromiter(P, dtype=np.float32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1, in <module>
#
# NameError: name 'a' is not defined

# %%
b = cops_analyze(['./pyruvate_HNCA/HNCA_nocop.ft3','./pyruvate_HNCA/HNCA_cop1.ft3','./pyruvate_HNCA/HNCA_cop3.ft3','./pyruvate_HNCA/HNCA_cop4.ft3','./pyruvate_HNCA/HNCA_cop5.ft3','./pyruvate_HNCA/HNCA_cop6.ft3'], mode='HNCA',pyruvate_on=True)

tb_nopyr=pd.read_fwf('./files/GB1_new.shifts', infer_nrows=300)
tb_nopyr = tb_nopyr.rename(columns={'w1':'CA','w2':'N', 'w3':'HN'})

#realign spectra
tb_nopyr = tb_nopyr.set_index(tb_nopyr['Assignment'])
tb_nopyr['is_sequential']=np.append([False], [len(tb_nopyr['Assignment'][i+1]) > len(tb_nopyr['Assignment'][i]) for i in range(len(tb_nopyr)-1)])
#tb_nopyr.loc[tb_nopyr['is_sequential'],'CA']=tb_nopyr[~tb_nopyr['is_sequential']][['CA']][:-1].to_numpy() #enforce the same CA

shifts_array = tb_nopyr[['CA','N', 'HN']].to_numpy(dtype=np.float32)
shifts_array[:,[0,1]]=shifts_array[:,[1,0]]


a = int_seq_match(b, peak_table_dir = './files/GB1_new.shifts', cops_mode='HNCA')
print(tb_nopyr['Assignment'][40])
print(shifts_array[40])
print(a.shifts_index.shape)
# Out:
# done!
# D21Ca-N-HN
# [115.789  49.417   7.163]
# (109, 3, 5)

# %%
import cProfile, pstats, io
from pstats import SortKey

pr = cProfile.Profile()
pr.enable()
b = cops_analyze(['./SHP2_Gradcops/SHP2_Grad1.ucsf','./SHP2_Gradcops/SHP2_Grad3.ucsf','./SHP2_Gradcops/SHP2_Grad5.ucsf','./SHP2_Gradcops/SHP2_Grad6.ucsf'], mode='HNCA',pyruvate_on=False, cop_num=[1,3,5,6])
pr.disable()
s = io.StringIO()
sortby = SortKey.CUMULATIVE
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
#          26411 function calls in 3.298 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    3.297    1.649 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3333(run_code)
#         2    0.000    0.000    3.297    1.649 {built-in method builtins.exec}
#         1    0.004    0.004    3.297    3.297 /tmp/ipykernel_16671/1202041506.py:6(<cell line: 6>)
#         1    0.000    0.000    3.293    3.293 /home/nmrbox/hwang/Documents/COPS_dev/cops_analysis.py:26(__init__)
#         1    0.000    0.000    3.285    3.285 /home/nmrbox/hwang/Documents/COPS_dev/cops_analysis.py:112(init_spectra)
#         4    0.000    0.000    3.285    0.821 /home/nmrbox/hwang/Documents/COPS_dev/cops_analysis.py:94(import_spectrum)
#         4    0.082    0.020    3.285    0.821 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:441(read_3D)
#        20    1.934    0.097    1.934    0.097 {method 'read' of '_io.BufferedReader' objects}
#         4    0.000    0.000    1.932    0.483 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:1309(get_data)
#         4    1.257    0.314    1.264    0.316 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:1566(untile_data3D)
#     17425    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.006    0.006 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:829(loadtxt)
#        26    0.001    0.000    0.004    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:1141(convert_row)
#         5    0.003    0.001    0.003    0.001 {built-in method io.open}
#      7098    0.003    0.000    0.003    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:723(_floatconv)
#         5    0.003    0.001    0.003    0.001 {built-in method posix.stat}
#         1    0.000    0.000    0.002    0.002 /home/nmrbox/hwang/Documents/COPS_dev/cops_analysis.py:82(<listcomp>)
#         4    0.000    0.000    0.002    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_interpolate.py:442(__init__)
#         4    0.000    0.000    0.002    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:1625(get_fileheader)
#         4    0.000    0.000    0.001    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py:1093(make_interp_spline)
#         1    0.000    0.000    0.001    0.001 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:155(open)
#         1    0.000    0.000    0.001    0.001 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:486(open)
#        27    0.000    0.000    0.001    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:974(split_line)
#        57    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        57    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py:797(_not_a_knot)
#        23    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/index_tricks.py:322(__getitem__)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/Documents/COPS_dev/cops_analysis.py:101(<listcomp>)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(moveaxis)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numeric.py:1404(moveaxis)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:32(make_uc)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:343(_findfile)
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(any)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numerictypes.py:597(find_common_type)
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_polyint.py:104(_reshape_yi)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/codeop.py:142(__call__)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numerictypes.py:573(_can_coerce_all)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:302(_isurl)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.frombuffer}
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2305(any)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py:27(_as_float_array)
#        20    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/urllib/parse.py:372(urlparse)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_polyint.py:49(__init__)
#        20    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numerictypes.py:356(issubdtype)
#         4    0.000    0.000    0.000    0.000 {scipy.interpolate._bspl._colloc}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:1652(fileheader2dic)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_polyint.py:112(_set_yi)
#         8    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numeric.py:1341(normalize_axis_tuple)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py:826(_process_deriv_spec)
#         7    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/posixpath.py:117(splitext)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/_methods.py:54(_any)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:246(__init__)
#        23    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/codecs.py:319(decode)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_1d)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py:19(_get_dtype)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ndim)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_polyint.py:132(_set_dtype)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3186(_update_code_co_name)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/posixpath.py:373(abspath)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#        59    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numerictypes.py:282(issubclass_)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_interpolate.py:581(fill_value)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/fileiobase.py:71(__init__)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:1714(axisheader2dic)
#        84    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        16    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:374(abspath)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:293(_possible_names)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/shape_base.py:23(atleast_1d)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(take)
#        23    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         3    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:263(_iszip)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1012(argsort)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/nmrglue/fileio/sparky.py:1689(get_axisheader)
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3164(ndim)
#         7    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/genericpath.py:121(_splitext)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/urllib/parse.py:437(urlsplit)
#        56    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numerictypes.py:582(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:93(take)
#        28    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:430(exists)
#       174    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/genericpath.py:16(exists)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/posixpath.py:334(normpath)
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:416(_sanitize_relative_path)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:321(__exit__)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/_bootlocale.py:33(getpreferredencoding)
#         4    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:1110(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_interpolate.py:318(_check_broadcast_up_to)
#        16    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numeric.py:1391(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/linalg/blas.py:383(getter)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/abc.py:117(__instancecheck__)
#        93    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:261(helper)
#         4    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:1135(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/traitlets/traitlets.py:566(__get__)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/posixpath.py:71(join)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(squeeze)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:114(__enter__)
#         5    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:130(keys)
#        48    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/dis.py:449(findlinestarts)
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:86(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        14    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/urllib/parse.py:114(_coerce_args)
#         8    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/posixpath.py:60(isabs)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py:251(construct_fast)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        12    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:123(__exit__)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_16671/1202041506.py:7(<cell line: 7>)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:748(_getconv)
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/traitlets/traitlets.py:535(get)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:769(_loadtxt_flatten_dtype_internal)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:280(_splitzipext)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py:815(_convert_string_aliases)
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/IPython/core/compilerop.py:174(extra_flags)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/codecs.py:309(__init__)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3284(compare)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1478(squeeze)
#         8    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55ea00c29740}
#         8    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        17    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numerictypes.py:649(<listcomp>)
#        20    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/interpolate/_interpolate.py:335(_do_extrapolate)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:993(<listcomp>)
#        24    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numeric.py:1466(<listcomp>)
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.ascontiguousarray}
#        26    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/npyio.py:1114(packer)
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2300(_any_dispatcher)
#         8    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3160(_ndim_dispatcher)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/scipy/_lib/_util.py:152(prod)
#         3    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/posixpath.py:41(_get_sep)
#        13    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/posixpath.py:131(splitdrive)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numeric.py:1400(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:256(__del__)
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:103(_load)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/urllib/parse.py:103(_noop)
#         2    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/IPython/core/interactiveshell.py:1181(user_global_ns)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/shape_base.py:19(_atleast_1d_dispatcher)
#         8    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1008(_argsort_dispatcher)
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/numerictypes.py:650(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:317(__init__)
#         3    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:89(_take_dispatcher)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_datasource.py:149(__getitem__)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_iotools.py:11(_decode_line)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         5    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:688(__init__)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/lib/_iotools.py:37(_is_string_like)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1474(_squeeze_dispatcher)
#         1    0.000    0.000    0.000    0.000 /home/nmrbox/hwang/miniconda3/envs/nmr/lib/python3.9/contextlib.py:319(__enter__)

# %%
import cProfile, pstats, io
from pstats import SortKey

pr = cProfile.Profile()
pr.enable()
int_seq_match(b, peak_table_dir = './files/GB1_new.shifts', cops_mode='HNCA')
pr.disable()
s = io.StringIO()
sortby = SortKey.TOTAL
ps = pstats.Stats(pr, stream=s).sort_stats(sortbt)
ps.print_stats()
print(s.getvalue())
# Out:
# done!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [58], in <cell line: 9>()
#       7 pr.disable()
#       8 s = io.StringIO()
# ----> 9 sortby = SortKey.TOTAL
#      10 ps = pstats.Stats(pr, stream=s).sort_stats(sortbt)
#      11 ps.print_stats()
#
# File ~/miniconda3/envs/nmr/lib/python3.9/enum.py:429, in EnumMeta.__getattr__(cls, name)
#     427     return cls._member_map_[name]
#     428 except KeyError:
# --> 429     raise AttributeError(name) from None
#
# AttributeError: TOTAL
